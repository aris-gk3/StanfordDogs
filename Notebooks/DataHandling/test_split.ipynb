# %%
from ml_project_util.load_preprocess import test_split

# %%
test_split(percent=40)
# Out:
# *** Training & Validation Classes are:
#
# 0. Affenpinscher (150 images)
# 1. Afghan_hound (239 images)
# 2. African_hunting_dog (169 images)
# 3. Airedale (202 images)
# 4. American_Staffordshire_terrier (164 images)
# 5. Appenzeller (151 images)
# 6. Australian_terrier (196 images)
# 7. Basenji (209 images)
# 8. Basset (175 images)
# 9. Beagle (195 images)
# 10. Bedlington_terrier (182 images)
# 11. Bernese_mountain_dog (218 images)
# 12. Black-and-tan_coonhound (159 images)
# 13. Blenheim_spaniel (188 images)
# 14. Bloodhound (187 images)
# 15. Bluetick (171 images)
# 16. Border_collie (150 images)
# 17. Border_terrier (172 images)
# 18. Borzoi (151 images)
# 19. Boston_bull (182 images)
# 20. Bouvier_des_Flandres (150 images)
# 21. Boxer (151 images)
# 22. Brabancon_griffon (153 images)
# 23. Briard (152 images)
# 24. Brittany_spaniel (152 images)
# 25. Bull_mastiff (156 images)
# 26. Cairn (197 images)
# 27. Cardigan (155 images)
# 28. Chesapeake_Bay_retriever (167 images)
# ...

# %%
import os

def count_files_recursive(directory):
    count = 0
    for root, dirs, files in os.walk(directory):
        count += len(files)
    return count

directory_path = 'C:\Programming_Files\JupyterVSCode\Multiclass_Transfer_Learning\StanfordDogs_120\Dataset\Train_val'
print(count_files_recursive(directory_path))
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\P'
# <>:9: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Aris_Work\AppData\Local\Temp\ipykernel_784\2913623476.py:9: SyntaxWarning: invalid escape sequence '\P'
#   directory_path = 'C:\Programming_Files\JupyterVSCode\Multiclass_Transfer_Learning\StanfordDogs_120\Dataset\Train_val'
# 20580
